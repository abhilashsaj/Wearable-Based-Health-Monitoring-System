# %%
import random 
import pandas as pd

# BLOOD SUGAR LEVELS (mg/dl)
# normal 
    # 70 - 99  fasting
    # <140 post meal
    
# prediabetes 
    # 100 - 125  fasting
    # 140 - 199 post meal
    
# Diabetes 
    # >126  fasting
    # >200 post meal
    
# convert mmol/l to mg/l     

post_meal = bool(random.getrandbits(1))
blood_sugar_level = random.randint(0,400)


print(post_meal, blood_sugar_level)


# Bronchiectasis 

# Patients are characterized by abnomrmal breathing and coughing frequency
# Reference BioSticker, Validac
breaths_per_minute = random.randint(12,30)
is_running = bool(random.getrandbits(1))
breath_shortness_severity = random.randint(0,10)
cough_frequency = random.randint(0,10)
cough_severity = random.randint(0,10)


# Coronary heart disease (CHD) 

# BP, Heart rate and Cholesterol

# Blood Pressure Categories (ref heart.org)

  # Normal 
  #   Systolic less than 120 and Diastolic less than 80
  # Elevated 
  #   Systolic 120 - 129 and Diastolic less than 80

  # High Blood Pressure 1 (HyperTension)
  #   Systolic 130 - 139 or Diastolic 80 - 89
  # High Blood Pressure 2 (HyperTension)
  #   Systolic 140 or higher or  Diastolic 90 or higher 
  # HyperTesnsive Chrisis
  #   Systolic higher than 180 or  Diastolic higher than 120 

# Cholestrol
  # Good Less than 200 (but the lower the better)
  # Borderline to moderately elevated	200–239
  # High	240 or higher


blood_pressure_sys = random.randint(50,250)
blood_pressure_dia = random.randint(50,250)
heart_rate = random.randint(60,200)
cholestorol = random.randint(100,500)

# Normal oxygen saturation is usually between 96% and 98%. Any level below this is
# considered dangerous and leads to hypoxemia.
# Use Oxygen Saturation parameters to predict Hypoxemia.

oxygen_saturation = random.randint(90,100)

# Moderate acute asthma is characterized by an oxygen saturation level of 92% to 95%, a pulse
# of 100 to 125 beats per minute, a respiratory rate of 20 to 30 breaths per minute.
# Use Oxygen saturation, BP, Respiration parameter to predict asthma.




data = [{'post_meal': bool(random.getrandbits(1)),
         'blood_sugar_level': random.randint(0,400),
         
         'breaths_per_minute': random.randint(12,30),
         'is_running': bool(random.getrandbits(1)),
         'breath_shortness_severity': random.randint(0,10),
         'cough_frequency': random.randint(0,10),
         'cough_severity': random.randint(0,10),
         
         'blood_pressure_sys': random.randint(50,250),
         'blood_pressure_dia': random.randint(50,250),
         'heart_rate': random.randint(60,200),
         'cholestorol': random.randint(60,200),
         'oxygen_saturation': random.randint(90,100)
        }] 


# Creates DataFrame. 
df = pd.DataFrame(data) 
  
# Print the data 
df
# Out:
# True 39
#    blood_pressure_dia  blood_pressure_sys  blood_sugar_level  \
# 0                 233                 126                233
#
#    breath_shortness_severity  breaths_per_minute  cholestorol  \
# 0                          3                  28          184
#
#    cough_frequency  cough_severity  heart_rate  is_running  oxygen_saturation  \
# 0                7               5         135        True                 93
#
#    post_meal
# 0       True

# %%
# BLOOD SUGAR LEVELS (mg/dl)
# normal 
    # 70 - 99  fasting
    # <140 post meal
    
# prediabetes 
    # 100 - 125  fasting
    # 140 - 199 post meal
    
# Diabetes 
    # >126  fasting
    # >200 post meal
    
# convert mmol/l to mg/l     

if data[0]['post_meal'] == True:
    if data[0]['blood_sugar_level'] < 140:
        data[0]['diabetes'] = 0
    if data[0]['blood_sugar_level'] > 140 and data[0]['blood_sugar_level'] < 199:
        data[0]['diabetes'] = 1
    if data[0]['blood_sugar_level'] > 200 :
        data[0]['diabetes'] = 2

if data[0]['post_meal'] == False:
    if data[0]['blood_sugar_level'] < 100:
        data[0]['diabetes'] = 0
    if data[0]['blood_sugar_level'] > 100 and data[0]['blood_sugar_level'] < 125:
        data[0]['diabetes'] = 1
    if data[0]['blood_sugar_level'] > 126 :
        data[0]['diabetes'] = 2
        
data
# Out:
# [{'post_meal': True,
#   'blood_sugar_level': 233,
#   'breaths_per_minute': 28,
#   'is_running': True,
#   'breath_shortness_severity': 3,
#   'cough_frequency': 7,
#   'cough_severity': 5,
#   'blood_pressure_sys': 126,
#   'blood_pressure_dia': 233,
#   'heart_rate': 135,
#   'cholestorol': 184,
#   'oxygen_saturation': 93,
#   'diabetes': 2}]

# %% [markdown]
# # Dataset Generation

# %%
import pandas as pd
import random 

df = pd.DataFrame([])

for i in range(1,10000):
    data = [{'post_meal': bool(random.getrandbits(1)),
         'blood_sugar_level': random.randint(0,400),
         
         'breaths_per_minute': random.randint(12,30),
         'is_running': bool(random.getrandbits(1)),
         'breath_shortness_severity': random.randint(0,10),
         'cough_frequency': random.randint(0,10),
         'cough_severity': random.randint(0,10),
         
         'blood_pressure_sys': random.randint(50,250),
         'blood_pressure_dia': random.randint(50,250),
         'heart_rate': random.randint(60,200),
         'cholestorol': random.randint(60,200),
         'oxygen_saturation': random.randint(90,100)
        }] 
    
    # labeling for diabete and prediabetes
    if data[0]['post_meal'] == True:
        if data[0]['blood_sugar_level'] < 140:
            data[0]['diabetes'] = 0
        if data[0]['blood_sugar_level'] > 140 and data[0]['blood_sugar_level'] < 199:
            data[0]['diabetes'] = 1
        if data[0]['blood_sugar_level'] > 200 :
            data[0]['diabetes'] = 2

    if data[0]['post_meal'] == False:
        if data[0]['blood_sugar_level'] < 100:
            data[0]['diabetes'] = 0
        if data[0]['blood_sugar_level'] > 100 and data[0]['blood_sugar_level'] < 125:
            data[0]['diabetes'] = 1
        if data[0]['blood_sugar_level'] > 126 :
            data[0]['diabetes'] = 2
    
    df = df.append(data)
    
    
df = df.reset_index(drop=True)
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#       blood_pressure_dia  blood_pressure_sys  blood_sugar_level  \
# 0                    146                 179                251
# 1                    188                 169                397
# 2                    201                 124                110
# 3                    215                 113                323
# 4                     75                 103                274
# 5                    229                 125                 88
# 6                    156                 182                 89
# 7                    182                 112                 39
# 8                    106                  86                306
# 9                    148                 161                363
# 10                    67                  80                176
# 11                    80                 145                367
# 12                    55                 229                344
# 13                    80                 184                282
# 14                   133                  97                336
# 15                   176                 147                 72
# 16                   249                 157                 11
# 17                    70                  86                 86
# 18                   235                 118                 18
# 19                   114                 122                 43
# 20                   236                 173                342
# 21                   233                 242                282
# 22                    69                 224                131
# 23                   144                  66                243
# 24                    55                 212                303
# 25                    76                 168                 97
# 26                   140                 223                218
# 27                   131                 246                206
# 28                   150                 226                 88
# 29                   150                 183                268
# ...                  ...                 ...                ...
# 9969                  87                 164                397
# 9970                 217                 101                195
# 9971                 223                 160                292
# 9972                 161                 146                396
# 9973                 177                 220                255
# 9974                 220                 238                300
# 9975                 157                 226                286
# 9976                 167                 176                200
# 9977                 194                 186                193
# 9978                 108                  80                282
# 9979                 213                 153                255
# 9980                 219                 194                164
# 9981                  96                 236                323
# 9982                 214                 171                109
# 9983                  53                 140                134
# 9984                  95                 117                 53
# 9985                 205                  82                187
# 9986                  97                 248                183
# 9987                 193                 207                348
# 9988                 238                 127                303
# 9989                 131                 185                277
# 9990                 174                 227                180
# 9991                 132                 153                378
# 9992                 216                  80                371
# 9993                 201                 145                397
# 9994                 222                 105                395
# 9995                 105                 126                238
# 9996                  93                  85                389
# 9997                 133                  78                209
# 9998                  51                 108                259
#
#       breath_shortness_severity  breaths_per_minute  cholestorol  \
# 0                             4                  30           80
# 1                            10                  29           76
# 2                             5                  30          133
# 3                             8                  22           74
# 4                             4                  29           61
# 5                             2                  29          190
# 6                             7                  15          149
# 7                             8                  16          133
# 8                             9                  22          100
# 9                             2                  16          194
# 10                            5                  12           99
# 11                            9                  23          187
# 12                            7                  20           66
# 13                            1                  22          123
# 14                            9                  17          136
# 15                           10                  23          124
# 16                            1                  25          167
# 17                            7                  21           68
# 18                            1                  13          191
# 19                            1                  30          101
# 20                            1                  24          154
# 21                            7                  21           71
# 22                            5                  19          131
# 23                           10                  21           81
# 24                           10                  15          191
# 25                            5                  23          164
# 26                            4                  20           69
# 27                            6                  22          200
# 28                            4                  21          194
# 29                            6                  30          183
# ...                         ...                 ...          ...
# 9969                          9                  21          104
# 9970                          0                  22          102
# 9971                          7                  22          188
# 9972                          0                  14           72
# 9973                          1                  14           78
# 9974                          8                  21          176
# 9975                          8                  18          183
# 9976                          8                  13          193
# 9977                          1                  14          132
# 9978                         10                  15          124
# 9979                          5                  26          125
# 9980                          7                  18          133
# 9981                          0                  20           73
# 9982                          6                  12          139
# 9983                          1                  30          145
# 9984                          2                  14          199
# 9985                          2                  17          143
# 9986                          7                  22           69
# 9987                          0                  21          103
# 9988                          1                  17          190
# 9989                          3                  29           73
# 9990                          8                  16          143
# 9991                          9                  29           80
# 9992                          5                  14           96
# 9993                          5                  29          146
# 9994                          4                  14           80
# 9995                          6                  23           69
# 9996                          5                  14          189
# 9997                          7                  19           83
# 9998                          6                  25           81
#
#       cough_frequency  cough_severity  diabetes  heart_rate  is_running  \
# 0                   8              10       2.0         130       False
# 1                  10               6       2.0          90       False
# 2                   7               9       1.0         120        True
# 3                   5               9       2.0         170       False
# 4                   7               1       2.0         153       False
# 5                   5               9       0.0         179       False
# 6                   5               6       0.0         197        True
# 7                   9               1       0.0         124       False
# 8                   1              10       2.0         109       False
# 9                   6               3       2.0         117        True
# 10                  7               0       2.0          80        True
# 11                  0               7       2.0          98       False
# 12                  5               0       2.0         131       False
# 13                  4               3       2.0          83       False
# 14                  1               4       2.0         179        True
# 15                  5               3       0.0         106        True
# 16                  4               4       0.0         155       False
# 17                  6               1       0.0          89        True
# 18                  7               2       0.0         136        True
# 19                  5               0       0.0          98        True
# 20                  9              10       2.0         166        True
# 21                  5               8       2.0         113       False
# 22                  4               4       0.0         183       False
# 23                  1               5       2.0          88       False
# 24                  5               6       2.0         191        True
# 25                  2               7       0.0          99       False
# 26                  6               7       2.0          74        True
# 27                  5               4       2.0          72        True
# 28                  6               7       0.0         197        True
# 29                  9               3       2.0         169        True
# ...               ...             ...       ...         ...         ...
# 9969                9               8       2.0         186        True
# 9970               10               6       2.0         122        True
# 9971               10               3       2.0         123       False
# 9972                6               8       2.0         159        True
# 9973                9               0       2.0         120       False
# 9974                1               6       2.0         167        True
# 9975                3              10       2.0         158       False
# 9976                8               6       2.0          60       False
# 9977                4              10       2.0          74       False
# 9978                3               6       2.0         105       False
# 9979                5               9       2.0         128        True
# 9980                8              10       2.0         139        True
# 9981                5               2       2.0          89       False
# 9982                4               3       1.0         181        True
# 9983                4               2       2.0         194       False
# 9984                8               3       0.0         156       False
# 9985                3               0       2.0         102        True
# 9986                1               7       2.0         185       False
# 9987                0              10       2.0          75        True
# 9988                6               4       2.0          83       False
# 9989                7               8       2.0         136        True
# 9990                5               5       1.0          98        True
# 9991                2               7       2.0         192       False
# 9992                9               9       2.0         158        True
# 9993                5              10       2.0         128        True
# 9994                4               4       2.0         193       False
# 9995               10               4       2.0         173        True
# 9996                0              10       2.0         132        True
# 9997                2               5       2.0         176       False
# 9998                1               5       2.0          85       False
#
#       oxygen_saturation  post_meal
# 0                    96      False
# 1                   100      False
# 2                    99      False
# 3                    96      False
# 4                    96       True
# 5                    99       True
# 6                    91      False
# 7                    93       True
# 8                    94      False
# 9                    95       True
# 10                   96      False
# 11                  100       True
# 12                   95       True
# 13                   95      False
# 14                   93      False
# 15                   91       True
# 16                   90       True
# 17                   91      False
# 18                   90       True
# 19                   93      False
# 20                   96       True
# 21                  100       True
# 22                   99       True
# 23                   94      False
# 24                   95       True
# 25                   92       True
# 26                   99      False
# 27                  100       True
# 28                   98       True
# 29                   95       True
# ...                 ...        ...
# 9969                 98       True
# 9970                100      False
# 9971                 92       True
# 9972                100      False
# 9973                 94       True
# 9974                 98       True
# 9975                 99      False
# 9976                100      False
# 9977                 91      False
# 9978                 91       True
# 9979                 98       True
# 9980                 95      False
# 9981                 97      False
# 9982                 96      False
# 9983                 92      False
# 9984                 96       True
# 9985                 96      False
# 9986                 92      False
# 9987                 97       True
# 9988                 97      False
# 9989                 96      False
# 9990                 94       True
# 9991                100       True
# 9992                 93       True
# 9993                 97      False
# 9994                100      False
# 9995                 96       True
# 9996                 98       True
# 9997                 96      False
# 9998                 98      False
#
# [9999 rows x 13 columns]

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
