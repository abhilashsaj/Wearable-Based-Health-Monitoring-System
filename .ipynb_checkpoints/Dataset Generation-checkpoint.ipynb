# %%
import random 
import pandas as pd

# BLOOD SUGAR LEVELS (mg/dl)
# normal 
    # 70 - 99  fasting
    # <140 post meal
    
# prediabetes 
    # 100 - 125  fasting
    # 140 - 199 post meal
    
# Diabetes 
    # >126  fasting
    # >200 post meal
    
# convert mmol/l to mg/l     

post_meal = bool(random.getrandbits(1))
blood_sugar_level = random.randint(0,400)


print(post_meal, blood_sugar_level)


# Bronchiectasis 

# Patients are characterized by abnomrmal breathing and coughing frequency
# Reference BioSticker, Validac
breaths_per_minute = random.randint(12,30)
is_running = bool(random.getrandbits(1))
breath_shortness_severity = random.randint(0,10)
cough_frequency = random.randint(0,10)
cough_severity = random.randint(0,10)


# Coronary heart disease (CHD) 

# BP, Heart rate and Cholesterol

# Blood Pressure Categories (ref heart.org)

  # Normal 
  #   Systolic less than 120 and Diastolic less than 80
  # Elevated 
  #   Systolic 120 - 129 and Diastolic less than 80

  # High Blood Pressure 1 (HyperTension)
  #   Systolic 130 - 139 or Diastolic 80 - 89
  # High Blood Pressure 2 (HyperTension)
  #   Systolic 140 or higher or  Diastolic 90 or higher 
  # HyperTesnsive Chrisis
  #   Systolic higher than 180 or  Diastolic higher than 120 

# Cholestrol
  # Good Less than 200 (but the lower the better)
  # Borderline to moderately elevated	200–239
  # High	240 or higher


blood_pressure_sys = random.randint(50,250)
blood_pressure_dia = random.randint(50,250)
heart_rate = random.randint(60,200)
cholestorol = random.randint(100,500)

# Normal oxygen saturation is usually between 96% and 98%. Any level below this is
# considered dangerous and leads to hypoxemia.
# Use Oxygen Saturation parameters to predict Hypoxemia.

oxygen_saturation = random.randint(90,100)

# Moderate acute asthma is characterized by an oxygen saturation level of 92% to 95%, a pulse
# of 100 to 125 beats per minute, a respiratory rate of 20 to 30 breaths per minute.
# Use Oxygen saturation, BP, Respiration parameter to predict asthma.




data = [{'post_meal': bool(random.getrandbits(1)),
         'blood_sugar_level': random.randint(0,400),
         
         'breaths_per_minute': random.randint(12,30),
         'is_running': bool(random.getrandbits(1)),
         'breath_shortness_severity': random.randint(0,10),
         'cough_frequency': random.randint(0,10),
         'cough_severity': random.randint(0,10),
         
         'blood_pressure_sys': random.randint(50,250),
         'blood_pressure_dia': random.randint(50,250),
         'heart_rate': random.randint(60,200),
         'cholestorol': random.randint(60,200),
         'oxygen_saturation': random.randint(90,100)
        }] 


# Creates DataFrame. 
df = pd.DataFrame(data) 
  
# Print the data 
df
# Out:
# True 39
#    blood_pressure_dia  blood_pressure_sys  blood_sugar_level  \
# 0                 233                 126                233
#
#    breath_shortness_severity  breaths_per_minute  cholestorol  \
# 0                          3                  28          184
#
#    cough_frequency  cough_severity  heart_rate  is_running  oxygen_saturation  \
# 0                7               5         135        True                 93
#
#    post_meal
# 0       True

# %%
# Moderate acute asthma is characterized by an oxygen saturation level of 92% to 95%, a pulse
# of 100 to 125 beats per minute, a respiratory rate of 20 to 30 breaths per minute.
# Use Oxygen saturation, BP, Respiration parameter to predict asthma.

'post_meal': bool(random.getrandbits(1)),
'blood_sugar_level': random.randint(0,400),

'breaths_per_minute': random.randint(12,30),
'is_running': bool(random.getrandbits(1)),
'breath_shortness_severity': random.randint(0,10),
'cough_frequency': random.randint(0,10),
'cough_severity': random.randint(0,10),

'blood_pressure_sys': random.randint(50,250),
'blood_pressure_dia': random.randint(50,250),
'heart_rate': random.randint(60,200),
'cholestorol': random.randint(60,200),
'oxygen_saturation': random.randint(90,100)


if data[0]['oxygen_saturation'] < 96 and  data[0]['oxygen_saturation'] > 91 and data[0]['heart_rate'] >= 100 and data[0]['heart_rate'] <=125 and data[0]['breaths_per_minute'] >= 20 nd data[0]['breaths_per_minute'] <= 30:
    data[0]['asthma'] = 1
else:
    data[0]['asthma'] = 0


data
# Out:
# [{'post_meal': False,
#   'blood_sugar_level': 259,
#   'breaths_per_minute': 25,
#   'is_running': False,
#   'breath_shortness_severity': 6,
#   'cough_frequency': 1,
#   'cough_severity': 5,
#   'blood_pressure_sys': 108,
#   'blood_pressure_dia': 51,
#   'heart_rate': 85,
#   'cholestorol': 81,
#   'oxygen_saturation': 98,
#   'diabetes': 2,
#   'bronchiectasis': 0}]

# %% [markdown]
# # Dataset Generation

# %%
import pandas as pd
import random 

df = pd.DataFrame([])

for i in range(1,10000):
    data = [{'post_meal': bool(random.getrandbits(1)),
         'blood_sugar_level': random.randint(0,400),
         
         'breaths_per_minute': random.randint(10,30),
         'is_running': bool(random.getrandbits(1)),
         'breath_shortness_severity': random.randint(0,10),
         'cough_frequency': random.randint(0,10),
         'cough_severity': random.randint(0,10),
         
         'blood_pressure_sys': random.randint(50,250),
         'blood_pressure_dia': random.randint(50,250),
         'heart_rate': random.randint(60,200),
         'cholestorol': random.randint(60,200),
         'oxygen_saturation': random.randint(90,100)
        }] 
    
    # labeling for diabete and prediabetes
    if data[0]['post_meal'] == True:
        if data[0]['blood_sugar_level'] < 140:
            data[0]['diabetes'] = 0
        if data[0]['blood_sugar_level'] > 140 and data[0]['blood_sugar_level'] < 199:
            data[0]['diabetes'] = 1
        if data[0]['blood_sugar_level'] > 200 :
            data[0]['diabetes'] = 2

    if data[0]['post_meal'] == False:
        if data[0]['blood_sugar_level'] < 100:
            data[0]['diabetes'] = 0
        if data[0]['blood_sugar_level'] > 100 and data[0]['blood_sugar_level'] < 125:
            data[0]['diabetes'] = 1
        if data[0]['blood_sugar_level'] > 126 :
            data[0]['diabetes'] = 2
    
    # labeling for bronchiectasis
    if data[0]['breaths_per_minute'] < 12 or data[0]['breaths_per_minute'] > 16 and data[0]['breath_shortness_severity'] > 6 and data[0]['cough_frequency'] > 6 and data[0]['cough_severity'] > 6:
        data[0]['bronchiectasis'] = 1
    else:
        data[0]['bronchiectasis'] = 0
    
    
    #   labeling for hypoxemia
    if data[0]['oxygen_saturation'] < 96 :
        data[0]['hypoxemia'] = 1
    else:
        data[0]['hypoxemia'] = 0
        
    # labeling for asthma
    if data[0]['oxygen_saturation'] < 96 and data[0]['oxygen_saturation'] > 91 and data[0]['heart_rate'] >= 100 and data[0]['heart_rate'] <=125 and data[0]['breaths_per_minute'] >= 20 and data[0]['breaths_per_minute'] <= 30:
        data[0]['asthma'] = 1
    else:
        data[0]['asthma'] = 0
        
    df = df.append(data)
    
    
df = df.reset_index(drop=True)
df
# Out:
#       asthma  blood_pressure_dia  blood_pressure_sys  blood_sugar_level  \
# 0          0                 185                 106                275
# 1          0                  77                 179                269
# 2          1                  78                 108                375
# 3          0                 164                 115                 57
# 4          0                 142                 203                334
# 5          0                 225                 155                371
# 6          0                 226                 250                 24
# 7          0                  57                 204                 10
# 8          0                 145                 148                351
# 9          0                 138                 100                107
# 10         0                 209                  89                 85
# 11         0                 107                  77                 28
# 12         0                  82                 131                395
# 13         0                 124                 136                295
# 14         0                 240                 166                 60
# 15         0                 238                 119                234
# 16         0                  72                 131                374
# 15            119                4               3       2.0         111
# 16            121               10               0       2.0         191
# 17            146                3               5       0.0         159
# 18            168                3               7       2.0         153
# 19             83                1               8       0.0         148
# 20            126                1               9       2.0         125
# 21            199                7               5       2.0         132
# 22            139                5               2       2.0          93
# 23            160                0               7       0.0         144
# 24            173                9               0       2.0         168
# 25            165                3               0       0.0         134
# 26            172                1               3       2.0         101
# 27            194               10               1       2.0         119
# 28             76                8               1       2.0         171
# 29            112                8               1       0.0          91
# ...           ...              ...             ...       ...         ...
# 9969          159                2               1       2.0         111
# 9970          184                5               5       1.0         146
# 9971           67                2               1       2.0          69
# 9972           79                9               4       2.0         194
# 9973          187                7               8       0.0         114
# 9974          169                8               1       0.0         148
# 9975          184                7               2       2.0         190
# 9976           65                9               4       2.0         118
# 9977          127                5               4       0.0         154
# 9978          166                7               2       0.0         179
# 9979          159                0               6       0.0          81
# 9980          133                7               6       0.0         149
# 9981          143               10               1       2.0          77
# 9982           93                5               4       2.0          75
# 9983          185                6               4       2.0         120
# 9984           82                7               4       0.0         125
# 9985          107                8               5       2.0         200
# 9986           79               10               3       2.0          89
# 9987          126                0               9       1.0         170
# 9988          142                2               1       2.0         134
# 9989           97                5               8       1.0          72
# 9990          110                4               9       2.0          87
# 9991           74                2               6       1.0         150
# 9992           70                8              10       0.0          82
# 9993           83                4               0       2.0          80
# 9994           66                3               1       0.0         151
# 9995          103                5               5       0.0         118
# 9996          102               10              10       2.0         114
# 9997          130                7               0       2.0         137
# 9998           65                7               6       NaN         123
#
#       hypoxemia  is_running  oxygen_saturation  post_meal
# 0             1       False                 91      False
# 1             1        True                 90      False
# 2             1       False                 92       True
# 3             1        True                 90      False
# 4             1        True                 92      False
# 5             0        True                 97      False
# 6             1        True                 94      False
# 7             0        True                100      False
# 8             1        True                 90       True
# 9             1        True                 92       True
# 10            1       False                 95       True
# 11            0        True                100       True
# 12            1       False                 93      False
# 13            1       False                 93      False
# 14            0        True                 99      False
# 15            1        True                 95       True
# 16            0       False                 98      False
# 17            1        True                 94       True
# 18            1       False                 91       True
# 19            0       False                 97      False
# 20            0       False                 99       True
# 21            0       False                 99      False
# 22            0        True                 98      False
# 23            1        True                 93      False
# 24            1       False                 94       True
# 25            0        True                100       True
# 26            0        True                100       True
# 27            0        True                 96       True
# 28            0       False                100       True
# 29            1        True                 95      False
# ...         ...         ...                ...        ...
# 9969          0       False                 97      False
# 9970          0       False                 97       True
# 9971          1        True                 94      False
# 9972          0        True                 97      False
# 9973          1        True                 94       True
# 9974          1       False                 91       True
# 9975          0       False                 99       True
# 9976          0       False                 98      False
# 9977          0       False                 98      False
# 9978          1        True                 95       True
# 9979          0        True                 96      False
# 9980          1        True                 93       True
# 9981          1        True                 95       True
# 9982          1       False                 92      False
# 9983          0        True                 96      False
# 9984          0       False                 99       True
# 9985          1       False                 95       True
# 9986          0       False                 99      False
# 9987          1        True                 93       True
# 9988          0        True                 96      False
# 9989          0        True                 99       True
# 9990          0       False                 99       True
# 9991          1       False                 92       True
# 9992          1       False                 93       True
# 9993          1        True                 95      False
# 9994          1       False                 90       True
# 9995          1       False                 94       True
# 9996          1        True                 94      False
# 9997          0        True                 97       True
# 9998          0        True                100      False
#
# [9999 rows x 16 columns]

# %% [markdown]
# # UCI heart disease dataset

# %%
df = pd.read_csv("heart.csv")

# %%
# df.columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']

# %%
features = df[['trestbps','chol','thalach']]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')
