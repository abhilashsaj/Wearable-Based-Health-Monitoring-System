# %%
import random 
import pandas as pd

# BLOOD SUGAR LEVELS (mg/dl)
# normal 
    # 70 - 99  fasting
    # <140 post meal
    
# prediabetes 
    # 100 - 125  fasting
    # 140 - 199 post meal
    
# Diabetes 
    # >126  fasting
    # >200 post meal
    
# convert mmol/l to mg/l     

post_meal = bool(random.getrandbits(1))
blood_sugar_level = random.randint(0,400)


print(post_meal, blood_sugar_level)


# Bronchiectasis 

# Patients are characterized by abnomrmal breathing and coughing frequency
# Reference BioSticker, Validac
breaths_per_minute = random.randint(12,30)
is_running = bool(random.getrandbits(1))
breath_shortness_severity = random.randint(0,10)
cough_frequency = random.randint(0,10)
cough_severity = random.randint(0,10)


# Coronary heart disease (CHD) 

# BP, Heart rate and Cholesterol

# Blood Pressure Categories (ref heart.org)

  # Normal 
  #   Systolic less than 120 and Diastolic less than 80
  # Elevated 
  #   Systolic 120 - 129 and Diastolic less than 80

  # High Blood Pressure 1 (HyperTension)
  #   Systolic 130 - 139 or Diastolic 80 - 89
  # High Blood Pressure 2 (HyperTension)
  #   Systolic 140 or higher or  Diastolic 90 or higher 
  # HyperTesnsive Chrisis
  #   Systolic higher than 180 or  Diastolic higher than 120 

# Cholestrol
  # Good Less than 200 (but the lower the better)
  # Borderline to moderately elevated	200–239
  # High	240 or higher


blood_pressure_sys = random.randint(50,250)
blood_pressure_dia = random.randint(50,250)
heart_rate = random.randint(60,200)
cholestorol = random.randint(100,500)

# Normal oxygen saturation is usually between 96% and 98%. Any level below this is
# considered dangerous and leads to hypoxemia.
# Use Oxygen Saturation parameters to predict Hypoxemia.

oxygen_saturation = random.randint(90,100)

# Moderate acute asthma is characterized by an oxygen saturation level of 92% to 95%, a pulse
# of 100 to 125 beats per minute, a respiratory rate of 20 to 30 breaths per minute.
# Use Oxygen saturation, BP, Respiration parameter to predict asthma.




data = [{'post_meal': bool(random.getrandbits(1)),
         'blood_sugar_level': random.randint(0,400),
         
         'breaths_per_minute': random.randint(12,30),
         'is_running': bool(random.getrandbits(1)),
         'breath_shortness_severity': random.randint(0,10),
         'cough_frequency': random.randint(0,10),
         'cough_severity': random.randint(0,10),
         
         'blood_pressure_sys': random.randint(50,250),
         'blood_pressure_dia': random.randint(50,250),
         'heart_rate': random.randint(60,200),
         'cholestorol': random.randint(60,200),
         'oxygen_saturation': random.randint(90,100)
        }] 


# Creates DataFrame. 
df = pd.DataFrame(data) 
  
# Print the data 
df
# Out:
# True 39
#    blood_pressure_dia  blood_pressure_sys  blood_sugar_level  \
# 0                 233                 126                233
#
#    breath_shortness_severity  breaths_per_minute  cholestorol  \
# 0                          3                  28          184
#
#    cough_frequency  cough_severity  heart_rate  is_running  oxygen_saturation  \
# 0                7               5         135        True                 93
#
#    post_meal
# 0       True

# %%
# Moderate acute asthma is characterized by an oxygen saturation level of 92% to 95%, a pulse
# of 100 to 125 beats per minute, a respiratory rate of 20 to 30 breaths per minute.
# Use Oxygen saturation, BP, Respiration parameter to predict asthma.

'post_meal': bool(random.getrandbits(1)),
'blood_sugar_level': random.randint(0,400),

'breaths_per_minute': random.randint(12,30),
'is_running': bool(random.getrandbits(1)),
'breath_shortness_severity': random.randint(0,10),
'cough_frequency': random.randint(0,10),
'cough_severity': random.randint(0,10),

'blood_pressure_sys': random.randint(50,250),
'blood_pressure_dia': random.randint(50,250),
'heart_rate': random.randint(60,200),
'cholestorol': random.randint(60,200),
'oxygen_saturation': random.randint(90,100)


if data[0]['oxygen_saturation'] < 96 and  data[0]['oxygen_saturation'] > 91 and data[0]['heart_rate'] >= 100 and data[0]['heart_rate'] <=125 and data[0]['breaths_per_minute'] >= 20 nd data[0]['breaths_per_minute'] <= 30:
    data[0]['asthma'] = 1
else:
    data[0]['asthma'] = 0


data
# Out:
# [{'post_meal': False,
#   'blood_sugar_level': 259,
#   'breaths_per_minute': 25,
#   'is_running': False,
#   'breath_shortness_severity': 6,
#   'cough_frequency': 1,
#   'cough_severity': 5,
#   'blood_pressure_sys': 108,
#   'blood_pressure_dia': 51,
#   'heart_rate': 85,
#   'cholestorol': 81,
#   'oxygen_saturation': 98,
#   'diabetes': 2,
#   'bronchiectasis': 0}]

# %% [markdown]
# # Dataset Generation

# %%
import pandas as pd
import random 

df = pd.DataFrame([])

for i in range(1,10000):
    data = [{'post_meal': bool(random.getrandbits(1)),
         'blood_sugar_level': random.randint(0,400),
         
         'breaths_per_minute': random.randint(12,30),
         'is_running': bool(random.getrandbits(1)),
         'breath_shortness_severity': random.randint(0,10),
         'cough_frequency': random.randint(0,10),
         'cough_severity': random.randint(0,10),
         
         'blood_pressure_sys': random.randint(50,250),
         'blood_pressure_dia': random.randint(50,250),
         'heart_rate': random.randint(60,200),
         'cholestorol': random.randint(60,200),
         'oxygen_saturation': random.randint(90,100)
        }] 
    
    # labeling for diabete and prediabetes
    if data[0]['post_meal'] == True:
        if data[0]['blood_sugar_level'] < 140:
            data[0]['diabetes'] = 0
        if data[0]['blood_sugar_level'] > 140 and data[0]['blood_sugar_level'] < 199:
            data[0]['diabetes'] = 1
        if data[0]['blood_sugar_level'] > 200 :
            data[0]['diabetes'] = 2

    if data[0]['post_meal'] == False:
        if data[0]['blood_sugar_level'] < 100:
            data[0]['diabetes'] = 0
        if data[0]['blood_sugar_level'] > 100 and data[0]['blood_sugar_level'] < 125:
            data[0]['diabetes'] = 1
        if data[0]['blood_sugar_level'] > 126 :
            data[0]['diabetes'] = 2
    
    # labeling for bronchiectasis
    if data[0]['breaths_per_minute'] < 12 and data[0]['breaths_per_minute'] > 16 and data[0]['breath_shortness_severity'] > 6 and data[0]['cough_frequency'] > 6 and data[0]['cough_severity'] > 6:
        data[0]['bronchiectasis'] = 1
    else:
        data[0]['bronchiectasis'] = 0
    
    
    #   labeling for hypoxemia
    if data[0]['oxygen_saturation'] < 96 :
        data[0]['hypoxemia'] = 1
    else:
        data[0]['hypoxemia'] = 0
        
    
    df = df.append(data)
    
    
df = df.reset_index(drop=True)
df
# Out:
#       blood_pressure_dia  blood_pressure_sys  blood_sugar_level  \
# 0                    210                 169                201
# 1                    197                 135                107
# 2                    240                 185                 12
# 3                    199                 173                 40
# 4                    176                 238                 81
# 5                     80                 215                360
# 6                    184                  71                283
# 7                     51                 129                 95
# 8                     99                 157                334
# 9                    160                 203                228
# 10                   193                  55                 81
# 11                   157                 131                 74
# 12                   203                 249                330
# 9             196                6               9       2.0         117
# 10             85                9               7       0.0         120
# 11            111                0               2       0.0         108
# 12            179                4               6       2.0         131
# 13             63                3               0       2.0          72
# 14            163                1               0       2.0         167
# 15            123               10               7       2.0          82
# 16            134                3               7       1.0         163
# 17             79                7              10       2.0         138
# 18            135                6               2       2.0         177
# 19            125                4               5       2.0         160
# 20            153                5               5       2.0         174
# 21            173                1               6       1.0         130
# 22             60                9              10       2.0         101
# 23            133                2               9       0.0          95
# 24             70                3               1       1.0         127
# 25             70                2               1       2.0         118
# 26            142                5               7       2.0         190
# 27            168                6               6       2.0         198
# 28            195                1               9       0.0         121
# 29             77                7               2       0.0         103
# ...           ...              ...             ...       ...         ...
# 9969          191                8               2       0.0         178
# 9970           76               10               5       2.0         147
# 9971          155                6               7       2.0         197
# 9972           98               10               7       0.0         148
# 9973           98                5               0       0.0         193
# 9974          115                5               5       2.0         198
# 9975          143                0               1       2.0         131
# 9976          144                0               9       2.0         148
# 9977          200               10               7       1.0         127
# 9978           94                0               7       0.0         153
# 9979          137                4              10       2.0         106
# 9980           92                8               7       0.0          92
# 9981          180                1               3       2.0         196
# 9982          116                3               2       2.0          60
# 9983          118               10               5       0.0          87
# 9984           60                6               7       2.0         144
# 9985           83                0               6       0.0          71
# 9986          124                9               9       2.0          77
# 9987          179                9               0       0.0          94
# 9988          100                1               7       0.0         108
# 9989          118               10               6       1.0         195
# 9990           60                7               9       2.0         186
# 9991          147                5               3       2.0         164
# 9992          112                8               8       2.0         109
# 9993          150                3               4       2.0         150
# 9994           98                2               9       0.0          61
# 9995          193                1               2       2.0         188
# 9996           68                4               0       2.0          60
# 9997          183                3               7       2.0          98
# 9998          139                2               3       NaN          71
#
#       is_running  oxygen_saturation  post_meal
# 0           True                 99      False
# 1           True                100       True
# 2          False                 97       True
# 3           True                 90       True
# 4           True                 90       True
# 5           True                 99       True
# 6          False                 96       True
# 7          False                 92      False
# 8          False                 97      False
# 9          False                 99       True
# 10          True                100      False
# 11         False                 96       True
# 12          True                 91      False
# 13         False                100      False
# 14          True                 90       True
# 15          True                 97      False
# 16         False                 96       True
# 17          True                 91      False
# 18         False                 95      False
# 19          True                 90      False
# 20         False                100       True
# 21          True                 96       True
# 22          True                 99       True
# 23          True                100       True
# 24          True                100       True
# 25          True                 98      False
# 26         False                 96      False
# 27         False                 92      False
# 28         False                 98      False
# 29          True                 97       True
# ...          ...                ...        ...
# 9969       False                 93       True
# 9970       False                 96      False
# 9971        True                100      False
# 9972        True                 90      False
# 9973       False                 94       True
# 9974       False                 96      False
# 9975       False                 97      False
# 9976       False                 98      False
# 9977       False                 93       True
# 9978        True                 93      False
# 9979       False                 99      False
# 9980        True                 91      False
# 9981        True                 90      False
# 9982       False                 91       True
# 9983        True                 90      False
# 9984       False                 97      False
# 9985       False                 90       True
# 9986        True                 99      False
# 9987       False                 97       True
# 9988       False                 99       True
# 9989        True                 94       True
# 9990       False                 94       True
# 9991       False                 99       True
# 9992        True                 92      False
# 9993       False                 98       True
# 9994       False                 90      False
# 9995        True                100      False
# 9996        True                 99      False
# 9997       False                 90       True
# 9998        True                 98       True
#
# [9999 rows x 14 columns]

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
